# %% [markdown]
# # BIOS512 Assignment #3

# %% [markdown]
# 📚 Import the `tidyverse` and the `palmerpenguins` packages. (**Hint:** use the `library` function)

# %%
library('tidyverse')
library('palmerpenguins')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Warning message:
# “package ‘palmerpenguins’ was built under R version 4.1.3”

# %%
penguins %>% head
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %% [markdown]
# Use `geom_bar` to make a histogram of penguin counts by `year`.

# %%
options(repr.plot.width=5, repr.plot.height=2)

p = ggplot(penguins, aes(y=year, fill=species, color=species))
    
p = p+geom_bar(binwidth=5, size=1)+
    labs(x="Number of Penguins", y="Years")+
    scale_color_brewer(palette='Dark2')+
    scale_fill_brewer(palette='Dark2')

p
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth”
# plot without title

# %% [markdown]
# Make a histogram or KDE plot that shows the distribution of body mass in each year. *Use a different theme than the default.*

# %%
library(scales)

# %%
options(repr.plot.width=20, repr.plot.height=15)

p = ggplot(penguins, aes(x=body_mass_g, fill=species, color=species)) + 
    geom_histogram(na.rm = TRUE, binwidth =80, position = 'identity', alpha=0.5)+
    facet_grid(vars(year))+
    labs(y="Number of Penguins", x="Body Mass in Grams", title="Histogram of Penguin Body Mass for Measurements Taken from 2007-2009")+
    scale_color_brewer(palette='Set2')+
    scale_fill_brewer(palette='Set2')+
    scale_x_continuous(labels = comma_format()) +
    theme_minimal() + 
    theme(legend.position = 'top')
p
# Out:
# plot without title

# %% [markdown]
# 🎉**BONUS**: can you adjust the `x-axis` labels to have "comma" formatting? (**Hint:** use the `comma_format()` function from the `scales` package.)

# %% [markdown]
# 👇 Here is the chart I made for reference.

# %% [markdown]
# ![image.png](attachment:7b611b75-f124-4315-9fa3-a4f57da5aa50.png)![image.png](attachment:f2c79a80-28de-419c-9e54-38a3d496656b.png)<img src="https://github.com/chuckpr/BIOS512/blob/main/assignments/mass_histograms3.png?raw=true" style="width:700px" />

# %% [markdown]
# Is there a difference between the body mass of male and female penguins? Use a scatter plot with jitter to compare the masses of male and female penguins. **Facet by `species` to compare within each species-group.**

# %%
options(repr.plot.width=7, repr.plot.height=6)

p = ggplot(penguins, aes(x=body_mass_g, y=sex)) + 
    geom_point(na.rm = TRUE, position = position_jitter(height = 0.4, width=0.2), shape=21, alpha=0.5, color='#e66101', fill='#e66101')+
    facet_wrap(vars(species))+
    theme(axis.text.x = element_text(angle = 45, hjust = 1))+
    labs(y="Male or Female Penguins", x="Body Mass in Grams")
p
# Out:
# plot without title

# %% [markdown]
# 👇 Here is my solution for reference.

# %% [markdown]
# <img src="https://github.com/chuckpr/BIOS512/blob/main/assignments/sex_differences_in_body_mass_within_species.png?raw=true" style="width: 600px" />
